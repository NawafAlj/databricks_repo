-- %% [markdown]
-- ##Products tables

-- %%
SELECT * FROM workspace.silver.prd_info;

-- %%
SELECT * FROM workspace.silver.erp_px_cat_g1v2;

-- %%
SELECT * FROM workspace.silver.erp_px_cat_g1v2 WHERE ID = 'CO-MF';

-- %%
SELECT * FROM workspace.silver.sales_details WHERE sls_prd_key = 'BK-R79Y-44';

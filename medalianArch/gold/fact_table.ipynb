-- %% [markdown]
-- ## events table(sales)

-- %%
SELECT * FROM workspace.silver.sales_details LIMIT 10;

-- %%
SELECT * FROM workspace.silver.sales_details AS sales
LEFT JOIN workspace.silver.prd_info AS prd
ON sales.sls_prd_key = prd.sls_prd_key;

-- %%
SELECT * FROM workspace.silver.sales_details AS sls
LEFT JOIN workspace.silver.crm_cust_info AS cst
ON sls.sls_cust_id = cst.cst_id;

-- %%
SELECT * FROM workspace.silver.crm_cust_info;

-- %%
SELECT * FROM workspace.silver.erp_cust_az12;

-- %%
SELECT * FROM workspace.silver.loc_a101;

-- %%
SELECT * FROM workspace.silver.loc_a101 WHERE CID = "AW00011122";

-- %%
SELECT * FROM workspace.silver.erp_cust_az12 WHERE CID = "AW00011213";

# %%
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %% [markdown]
# ##cust_info

# %%
TABLE_PATH = "workspace.bronze_new.crm_20260221135014660445_cust_info"

display(spark.sql("SELECT * FROM " + TABLE_PATH + " WHERE cst_firstname = 'Sarah'"))

# %%
TABLE_PATH = "workspace.bronze_new.crm_20260221135014660445_cust_info"

display(spark.sql("SELECT count(*) FROM " + TABLE_PATH + " WHERE cst_gndr IS NULL"))

# %%
TABLE_PATH = "workspace.bronze_new.crm_20260221135014660445_cust_info"

display(spark.read.table(TABLE_PATH))

# %%
TABLE_PATH = "workspace.silver.crm_cust_info"

display(spark.read.table(TABLE_PATH))

# %% [markdown]
# ##cust_az12

# %%
TABLE_PATH = "workspace.silver.erp_cust_az12"

display(spark.read.table(TABLE_PATH))

# %% [markdown]
# ##px_cat_g1v2

# %%
TABLE_PATH = "workspace.silver.erp_px_cat_g1v2"

display(spark.read.table(TABLE_PATH))

# %%
TABLE_PATH = "workspace.silver.erp_px_cat_g1v2"

display(spark.read.table(TABLE_PATH))

# %%
TABLE_PATH = "workspace.silver.loc_a101"

display(spark.read.table(TABLE_PATH))

# %%
TABLE_PATH = "workspace.silver.prd_info"

display(spark.read.table(TABLE_PATH))

# %%
TABLE_PATH = "workspace.silver.sales_details"

display(spark.read.table(TABLE_PATH))

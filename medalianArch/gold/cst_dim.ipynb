-- %%
SELECT * FROM workspace.silver.crm_cust_info;

-- %%
SELECT * FROM workspace.silver.crm_cust_info AS cus
LEFT JOIN workspace.silver.erp_cust_az12 AS cst
ON cus.cst_key = cst.CID;

-- %%
SELECT * FROM workspace.silver.crm_cust_info AS cst
LEFT JOIN workspace.silver.loc_a101 AS loc
ON cst.cst_key = loc.CID;

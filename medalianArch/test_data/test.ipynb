-- %%
SELECT count(*) FROM workspace.gold.fact_sales;

-- %%
SELECT * FROM workspace.gold.fact_sales WHERE quantity > 1;

-- %%
SELECT * FROM workspace.gold.dim_customer;

-- %%
SELECT * FROM workspace.gold.dim_product;
